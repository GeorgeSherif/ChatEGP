# %% [markdown]
# <a href="https://colab.research.google.com/github/GeorgeSherif/NLP-ChatEGP/blob/main/Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the bar chart
classes = ['English Dataset (Training)', 'Arabic Dataset (Testing)']
subclasses = ['Without Preprocessing', 'Using Preprocessing', 'Using Data Augmentation']
values = np.array([[87.1, 81.8, 87.0], 
                   [83.8, 81.8, 87.0]
                   ])

# Number of subclasses and their width
num_subclasses = len(subclasses)
width = 0.2

# Plotting the grouped bar chart
fig, ax = plt.subplots()
for i in range(num_subclasses):
    ax.bar(np.arange(len(classes)) + i * width, values[:, i], width=width, label=subclasses[i])

    # Adding labels on top of the bars
    for j, v in enumerate(values[:, i]):
        ax.text(j + i * width, v + 1, str(v), ha='center')

# Adding labels and title
#ax.set_xlabel('Classes')
#ax.set_ylabel('Values')
ax.set_title('Accuracies Comparison')
ax.set_xticks(np.arange(len(classes)) + (num_subclasses - 1) * width / 2)
ax.set_xticklabels(classes, ha='center')
ax.legend()
ax.set_ylim(bottom=75)
ax.set_yticks(np.arange(75, np.max(values) + 10, 10))
ax.grid(False)

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example sequence of numbers
Epochs = ["E1", "E2", "E3","E4", "E5","E6", "E7","E8","E9", "E10", "E11","E12", "E13","E14", "E15","E16"]
sequence = [80.4, 85.3, 85.7, 84.3, 84.8, 86.8, 86.8, 85.7, 87.1, 86.0, 84.8, 85.4, 85.4, 85.7, 84.8, 84.8]

fig, ax = plt.subplots(figsize=(9, 4))

# Plotting the sequence as a line plot
plt.plot(Epochs, sequence)
ax.grid(False)

# Adding numbers on the nodes
for i, value in enumerate(sequence):
    plt.text(i, value, str(value), ha='center', va='bottom')
# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Accuracies of Training Epochs Before Preprocessing (English Dataset)')

ax.set_ylim(bottom=80)
ax.set_ylim(top=90)

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example sequence of numbers
Epochs = ["E1", "E2", "E3","E4", "E5","E6", "E7","E8","E9", "E10", "E11","E12", "E13","E14", "E15","E16"]
sequence = [74.9, 75.7, 79.6, 80.1, 78.2, 80.4, 81.8, 81.2, 81.2, 80.9, 80.9, 80.1, 80.4, 80.4, 80.4, 80.7]

fig, ax = plt.subplots(figsize=(9, 4))

# Plotting the sequence as a line plot
plt.plot(Epochs, sequence)
ax.grid(False)

# Adding numbers on the nodes
for i, value in enumerate(sequence):
    plt.text(i, value, str(value), ha='center', va='bottom')
# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Accuracies of Training Epochs After Preprocessing (English Dataset)')

ax.set_ylim(bottom=70)
ax.set_ylim(top=85)

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example sequence of numbers
Epochs = ["E1", "E2", "E3","E4", "E5","E6", "E7","E8","E9", "E10", "E11","E12", "E13","E14", "E15","E16"]
sequence = [81.4, 85.5, 87.0, 86.3, 87.6, 85.9, 86.7, 86.2, 85.9, 86.6, 86.7, 86.2, 87.0, 85.9, 86.5, 86.0]


fig, ax = plt.subplots(figsize=(9, 4))

# Plotting the sequence as a line plot
plt.plot(Epochs, sequence)
ax.grid(False)

# Adding numbers on the nodes
for i, value in enumerate(sequence):
    plt.text(i, value, str(value), ha='center', va='bottom')
# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Accuracies of Training Epochs After Data Augmentation (English Dataset)')

ax.set_ylim(bottom=80)
ax.set_ylim(top=90)

# Displaying the plot
plt.show()
